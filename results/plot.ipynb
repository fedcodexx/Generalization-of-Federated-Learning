# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
fedavg_test_iid = pd.read_csv('iid/mnist_FedAvg_cnn_00.005_test.csv', usecols=[1], header = 0, names=['fedavg'])
fedavg_test_iid = np.array(fedavg_test_iid['fedavg'].to_list())

fedavg_train_iid = pd.read_csv('iid/mnist_FedAvg_cnn_00.005_train.csv', usecols=[1], header = 0, names=['fedavg'])
fedavg_train_iid = np.array(fedavg_train_iid['fedavg'].to_list())

scaffold_test_iid = pd.read_csv('iid/mnist_SCAFFOLD_cnn_00.003_test.csv', usecols=[1], header = 0, names=['scaffold'])
scaffold_test_iid = np.array(scaffold_test_iid['scaffold'].to_list())

scaffold_train_iid = pd.read_csv('iid/mnist_SCAFFOLD_cnn_00.003_train.csv', usecols=[1], header = 0, names=['scaffold'])
scaffold_train_iid = np.array(scaffold_train_iid['scaffold'].to_list())

prox_test_iid = pd.read_csv('iid/mnist_FedProx_cnn_00.005_test.csv', usecols=[1], header = 0, names=['prox'])
prox_test_iid = np.array(prox_test_iid['prox'].to_list())

prox_train_iid = pd.read_csv('iid/mnist_FedProx_cnn_00.005_train.csv', usecols=[1], header = 0, names=['prox'])
prox_train_iid = np.array(prox_train_iid['prox'].to_list())

# %%
fedavg_test_pat = pd.read_csv('pat/mnist_FedAvg_cnn_00.005_test.csv', usecols=[1], header = 0, names=['fedavg'])
fedavg_test_pat = np.array(fedavg_test_pat['fedavg'].to_list())

fedavg_train_pat = pd.read_csv('pat/mnist_FedAvg_cnn_00.005_train.csv', usecols=[1], header = 0, names=['fedavg'])
fedavg_train_pat = np.array(fedavg_train_pat['fedavg'].to_list())

scaffold_test_pat = pd.read_csv('pat/mnist_SCAFFOLD_cnn_00.003_test.csv', usecols=[1], header = 0, names=['scaffold'])
scaffold_test_pat = np.array(scaffold_test_pat['scaffold'].to_list())

scaffold_train_pat = pd.read_csv('pat/mnist_SCAFFOLD_cnn_00.003_train.csv', usecols=[1], header = 0, names=['scaffold'])
scaffold_train_pat = np.array(scaffold_train_pat['scaffold'].to_list())

prox_test_pat = pd.read_csv('pat/mnist_FedProx_cnn_00.005_test.csv', usecols=[1], header = 0, names=['prox'])
prox_test_pat = np.array(prox_test_pat['prox'].to_list())

prox_train_pat = pd.read_csv('pat/mnist_FedProx_cnn_00.005_train.csv', usecols=[1], header = 0, names=['prox'])
prox_train_pat = np.array(prox_train_pat['prox'].to_list())

# %%
fedavg_test_08 = pd.read_csv('pat_0.8/mnist_FedAvg_cnn_00.005_test.csv', usecols=[1], header = 0, names=['fedavg'])
fedavg_test_08 = np.array(fedavg_test_08['fedavg'].to_list())

fedavg_train_08 = pd.read_csv('pat_0.8/mnist_FedAvg_cnn_00.005_train.csv', usecols=[1], header = 0, names=['fedavg'])
fedavg_train_08 = np.array(fedavg_train_08['fedavg'].to_list())

scaffold_test_08 = pd.read_csv('pat_0.8/mnist_SCAFFOLD_cnn_00.003_test.csv', usecols=[1], header = 0, names=['scaffold'])
scaffold_test_08 = np.array(scaffold_test_08['scaffold'].to_list())

scaffold_train_08 = pd.read_csv('pat_0.8/mnist_SCAFFOLD_cnn_00.003_train.csv', usecols=[1], header = 0, names=['scaffold'])
scaffold_train_08 = np.array(scaffold_train_08['scaffold'].to_list())

prox_test_08 = pd.read_csv('mnist_FedProx_cnn_00.005_test.csv', usecols=[1], header = 0, names=['prox'])
prox_test_08 = np.array(prox_test_08['prox'].to_list())

prox_train_08 = pd.read_csv('mnist_FedProx_cnn_00.005_train.csv', usecols=[1], header = 0, names=['prox'])
prox_train_08 = np.array(prox_train_08['prox'].to_list())

# %%
fedavg_test_05 = pd.read_csv('pat_0.5/mnist_FedAvg_cnn_00.005_test.csv', usecols=[1], header = 0, names=['fedavg'])
fedavg_test_05 = np.array(fedavg_test_05['fedavg'].to_list())

fedavg_train_05 = pd.read_csv('pat_0.5/mnist_FedAvg_cnn_00.005_train.csv', usecols=[1], header = 0, names=['fedavg'])
fedavg_train_05 = np.array(fedavg_train_05['fedavg'].to_list())

scaffold_test_05 = pd.read_csv('pat_0.5/mnist_SCAFFOLD_cnn_00.003_test.csv', usecols=[1], header = 0, names=['scaffold'])
scaffold_test_05 = np.array(scaffold_test_05['scaffold'].to_list())

scaffold_train_05 = pd.read_csv('pat_0.5/mnist_SCAFFOLD_cnn_00.003_train.csv', usecols=[1], header = 0, names=['scaffold'])
scaffold_train_05 = np.array(scaffold_train_05['scaffold'].to_list())

prox_test_05 = pd.read_csv('pat_0.5/mnist_FedProx_cnn_00.005_test.csv', usecols=[1], header = 0, names=['prox'])
prox_test_05 = np.array(prox_test_05['prox'].to_list())

prox_train_05 = pd.read_csv('pat_0.5/mnist_FedProx_cnn_00.005_train.csv', usecols=[1], header = 0, names=['prox'])
prox_train_05 = np.array(prox_train_05['prox'].to_list())

# %%
fedavg_test_02 = pd.read_csv('pat_0.2/mnist_FedAvg_cnn_00.005_test.csv', usecols=[1], header = 0, names=['fedavg'])
fedavg_test_02 = np.array(fedavg_test_02['fedavg'].to_list())

fedavg_train_02 = pd.read_csv('pat_0.2/mnist_FedAvg_cnn_00.005_train.csv', usecols=[1], header = 0, names=['fedavg'])
fedavg_train_02 = np.array(fedavg_train_02['fedavg'].to_list())

scaffold_test_02 = pd.read_csv('pat_0.2/mnist_SCAFFOLD_cnn_00.003_test.csv', usecols=[1], header = 0, names=['scaffold'])
scaffold_test_02 = np.array(scaffold_test_02['scaffold'].to_list())

scaffold_train_02 = pd.read_csv('pat_0.2/mnist_SCAFFOLD_cnn_00.003_train.csv', usecols=[1], header = 0, names=['scaffold'])
scaffold_train_02 = np.array(scaffold_train_02['scaffold'].to_list())

prox_test_02 = pd.read_csv('pat_0.2/mnist_FedProx_cnn_00.005_test.csv', usecols=[1], header = 0, names=['prox'])
prox_test_02 = np.array(prox_test_02['prox'].to_list())

prox_train_02 = pd.read_csv('pat_0.2/mnist_FedProx_cnn_00.005_train.csv', usecols=[1], header = 0, names=['prox'])
prox_train_02 = np.array(prox_train_02['prox'].to_list())

# %%
ls = [0.205 - 0.02*i for i in range(11)]
ls
# Out:
# [0.205,
#  0.185,
#  0.16499999999999998,
#  0.145,
#  0.12499999999999999,
#  0.10499999999999998,
#  0.08499999999999999,
#  0.06499999999999997,
#  0.044999999999999984,
#  0.024999999999999994,
#  0.004999999999999977]

# %%
avg_iid = []
avg_02 = []
avg_05 = []
avg_08 = []
avg_pat = []
for c in ls:
    for i in range(len(fedavg_train_iid)):
        if fedavg_train_iid[i] < c:
            avg_iid.append(abs(fedavg_test_iid[i]-fedavg_train_iid[i]))
            break
    
    for i in range(len(fedavg_train_02)):
        if fedavg_train_02[i] < c:
            avg_02.append(abs(fedavg_test_02[i]-fedavg_train_02[i]))
            break
    
    for i in range(len(fedavg_train_05)):
        if fedavg_train_05[i] < c:
            avg_05.append(abs(fedavg_test_05[i]-fedavg_train_05[i]))
            break
    
    for i in range(len(fedavg_train_08)):
        if fedavg_train_08[i] < c:
            avg_08.append(abs(fedavg_test_08[i]-fedavg_train_08[i]))
            break

    for i in range(len(fedavg_train_pat)):
        if fedavg_train_pat[i] < c:
            avg_pat.append(abs(fedavg_test_pat[i]-fedavg_train_pat[i]))
            break

# %%
ls1 = [0, 0.2, 0.5, 0.8, 1]

# %%
avg_02 = []
avg_008 = []
avg_005 = []
avg_001 = []
avg_0005 = []

c = 0.2
for i in range(len(fedavg_train_iid)):
    if fedavg_train_iid[i] < c:
        avg_02.append(abs(fedavg_test_iid[i]-fedavg_train_iid[i]))
        break

for i in range(len(fedavg_train_02)):
    if fedavg_train_02[i] < c:
        avg_02.append(abs(fedavg_test_02[i]-fedavg_train_02[i]))
        break

for i in range(len(fedavg_train_05)):
    if fedavg_train_05[i] < c:
        avg_02.append(abs(fedavg_test_05[i]-fedavg_train_05[i]))
        break

for i in range(len(fedavg_train_08)):
    if fedavg_train_08[i] < c:
        avg_02.append(abs(fedavg_test_08[i]-fedavg_train_08[i]))
        break
for i in range(len(fedavg_train_pat)):
    if fedavg_train_pat[i] < c:
        avg_02.append(abs(fedavg_test_pat[i]-fedavg_train_pat[i]))
        break

c = 0.1
for i in range(len(fedavg_train_iid)):
    if fedavg_train_iid[i] < c:
        avg_008.append(abs(fedavg_test_iid[i]-fedavg_train_iid[i]))
        break

for i in range(len(fedavg_train_02)):
    if fedavg_train_02[i] < c:
        avg_008.append(abs(fedavg_test_02[i]-fedavg_train_02[i]))
        break

for i in range(len(fedavg_train_05)):
    if fedavg_train_05[i] < c:
        avg_008.append(abs(fedavg_test_05[i]-fedavg_train_05[i]))
        break

for i in range(len(fedavg_train_08)):
    if fedavg_train_08[i] < c:
        avg_008.append(abs(fedavg_test_08[i]-fedavg_train_08[i]))
        break
for i in range(len(fedavg_train_pat)):
    if fedavg_train_pat[i] < c:
        avg_008.append(abs(fedavg_test_pat[i]-fedavg_train_pat[i]))
        break

c = 0.05
for i in range(len(fedavg_train_iid)):
    if fedavg_train_iid[i] < c:
        avg_005.append(abs(fedavg_test_iid[i]-fedavg_train_iid[i]))
        break

for i in range(len(fedavg_train_02)):
    if fedavg_train_02[i] < c:
        avg_005.append(abs(fedavg_test_02[i]-fedavg_train_02[i]))
        break

for i in range(len(fedavg_train_05)):
    if fedavg_train_05[i] < c:
        avg_005.append(abs(fedavg_test_05[i]-fedavg_train_05[i]))
        break

for i in range(len(fedavg_train_08)):
    if fedavg_train_08[i] < c:
        avg_005.append(abs(fedavg_test_08[i]-fedavg_train_08[i]))
        break
for i in range(len(fedavg_train_pat)):
    if fedavg_train_pat[i] < c:
        avg_005.append(abs(fedavg_test_pat[i]-fedavg_train_pat[i]))
        break

c = 0.01
for i in range(len(fedavg_train_iid)):
    if fedavg_train_iid[i] < c:
        avg_001.append(abs(fedavg_test_iid[i]-fedavg_train_iid[i]))
        break

for i in range(len(fedavg_train_02)):
    if fedavg_train_02[i] < c:
        avg_001.append(abs(fedavg_test_02[i]-fedavg_train_02[i]))
        break

for i in range(len(fedavg_train_05)):
    if fedavg_train_05[i] < c:
        avg_001.append(abs(fedavg_test_05[i]-fedavg_train_05[i]))
        break

for i in range(len(fedavg_train_08)):
    if fedavg_train_08[i] < c:
        avg_001.append(abs(fedavg_test_08[i]-fedavg_train_08[i]))
        break
for i in range(len(fedavg_train_pat)):
    if fedavg_train_pat[i] < c:
        avg_001.append(abs(fedavg_test_pat[i]-fedavg_train_pat[i]))
        break

c = 0.005
for i in range(len(fedavg_train_iid)):
    if fedavg_train_iid[i] < c:
        avg_0005.append(abs(fedavg_test_iid[i]-fedavg_train_iid[i]))
        break

for i in range(len(fedavg_train_02)):
    if fedavg_train_02[i] < c:
        avg_0005.append(abs(fedavg_test_02[i]-fedavg_train_02[i]))
        break

for i in range(len(fedavg_train_05)):
    if fedavg_train_05[i] < c:
        avg_0005.append(abs(fedavg_test_05[i]-fedavg_train_05[i]))
        break

for i in range(len(fedavg_train_08)):
    if fedavg_train_08[i] < c:
        avg_0005.append(abs(fedavg_test_08[i]-fedavg_train_08[i]))
        break
for i in range(len(fedavg_train_pat)):
    if fedavg_train_pat[i] < c:
        avg_0005.append(abs(fedavg_test_pat[i]-fedavg_train_pat[i]))
        break

# %%
plt.plot(ls1, avg_02, 'c', marker=(5, 2))
plt.plot(ls1, avg_008, 'b', marker=(5, 2))
plt.plot(ls1[:4], avg_005, 'r', marker=(5, 2))
plt.plot(ls1[:4], avg_001, 'g', marker=(5, 2))
plt.plot(ls1[:3], avg_0005, 'y', marker=(5, 2))
plt.legend(['train loss 0.2', 'train loss 0.1', 'train loss 0.05', 'train loss 0.01', 'train loss 0.005'])
plt.xlabel(r'$\rho$, ' + 'heterogeneity level of local data distributions')
plt.ylabel('abs(test loss - train loss)')
plt.rcParams.update({'font.size': 14})
plt.savefig('fedavg.pdf')

# %%
avg_02 = []
avg_008 = []
avg_005 = []
avg_001 = []
avg_0005 = []

c = 0.2
for i in range(len(scaffold_train_iid)):
    if scaffold_train_iid[i] < c:
        avg_02.append(abs(scaffold_test_iid[i]-scaffold_train_iid[i]))
        break

for i in range(len(scaffold_train_02)):
    if scaffold_train_02[i] < c:
        avg_02.append(abs(scaffold_test_02[i]-scaffold_train_02[i]))
        break

for i in range(len(scaffold_train_05)):
    if scaffold_train_05[i] < c:
        avg_02.append(abs(scaffold_test_05[i]-scaffold_train_05[i]))
        break

for i in range(len(scaffold_train_08)):
    if scaffold_train_08[i] < c:
        avg_02.append(abs(scaffold_test_08[i]-scaffold_train_08[i]))
        break
for i in range(len(scaffold_train_pat)):
    if scaffold_train_pat[i] < c:
        avg_02.append(abs(scaffold_test_pat[i]-scaffold_train_pat[i]))
        break

c = 0.1
for i in range(len(scaffold_train_iid)):
    if scaffold_train_iid[i] < c:
        avg_008.append(abs(scaffold_test_iid[i]-scaffold_train_iid[i]))
        break

for i in range(len(scaffold_train_02)):
    if scaffold_train_02[i] < c:
        avg_008.append(abs(scaffold_test_02[i]-scaffold_train_02[i]))
        break

for i in range(len(scaffold_train_05)):
    if scaffold_train_05[i] < c:
        avg_008.append(abs(scaffold_test_05[i]-scaffold_train_05[i]))
        break

for i in range(len(scaffold_train_08)):
    if scaffold_train_08[i] < c:
        avg_008.append(abs(scaffold_test_08[i]-scaffold_train_08[i]))
        break
for i in range(len(scaffold_train_pat)):
    if scaffold_train_pat[i] < c:
        avg_008.append(abs(scaffold_test_pat[i]-scaffold_train_pat[i]))
        break

c = 0.05
for i in range(len(fedavg_train_iid)):
    if fedavg_train_iid[i] < c:
        avg_005.append(abs(fedavg_test_iid[i]-fedavg_train_iid[i]))
        break

for i in range(len(fedavg_train_02)):
    if fedavg_train_02[i] < c:
        avg_005.append(abs(fedavg_test_02[i]-fedavg_train_02[i]))
        break

for i in range(len(fedavg_train_05)):
    if fedavg_train_05[i] < c:
        avg_005.append(abs(fedavg_test_05[i]-fedavg_train_05[i]))
        break

for i in range(len(fedavg_train_08)):
    if fedavg_train_08[i] < c:
        avg_005.append(abs(fedavg_test_08[i]-fedavg_train_08[i]))
        break
for i in range(len(fedavg_train_pat)):
    if fedavg_train_pat[i] < c:
        avg_005.append(abs(fedavg_test_pat[i]-fedavg_train_pat[i]))
        break

c = 0.01
for i in range(len(fedavg_train_iid)):
    if fedavg_train_iid[i] < c:
        avg_001.append(abs(fedavg_test_iid[i]-fedavg_train_iid[i]))
        break

for i in range(len(fedavg_train_02)):
    if fedavg_train_02[i] < c:
        avg_001.append(abs(fedavg_test_02[i]-fedavg_train_02[i]))
        break

for i in range(len(fedavg_train_05)):
    if fedavg_train_05[i] < c:
        avg_001.append(abs(fedavg_test_05[i]-fedavg_train_05[i]))
        break

for i in range(len(fedavg_train_08)):
    if fedavg_train_08[i] < c:
        avg_001.append(abs(fedavg_test_08[i]-fedavg_train_08[i]))
        break
for i in range(len(fedavg_train_pat)):
    if fedavg_train_pat[i] < c:
        avg_001.append(abs(fedavg_test_pat[i]-fedavg_train_pat[i]))
        break

c = 0.005
for i in range(len(fedavg_train_iid)):
    if fedavg_train_iid[i] < c:
        avg_0005.append(abs(fedavg_test_iid[i]-fedavg_train_iid[i]))
        break

for i in range(len(fedavg_train_02)):
    if fedavg_train_02[i] < c:
        avg_0005.append(abs(fedavg_test_02[i]-fedavg_train_02[i]))
        break

for i in range(len(fedavg_train_05)):
    if fedavg_train_05[i] < c:
        avg_0005.append(abs(fedavg_test_05[i]-fedavg_train_05[i]))
        break

for i in range(len(fedavg_train_08)):
    if fedavg_train_08[i] < c:
        avg_0005.append(abs(fedavg_test_08[i]-fedavg_train_08[i]))
        break
for i in range(len(fedavg_train_pat)):
    if fedavg_train_pat[i] < c:
        avg_0005.append(abs(fedavg_test_pat[i]-fedavg_train_pat[i]))
        break

# %%
import matplotlib.ticker as ticker

tick_spacing = 1

fig, ax = plt.subplots(1,1)
ax.plot(ls,avg_iid)
ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
plt.show()

# %%
plt.plot(fedavg_test_iid[30:], c='r')
plt.plot(fedavg_train_iid[30:], c='b')
plt.plot(fedavg_test_pat[30:], c='y')
plt.plot(fedavg_train_pat[30:], c='g')
plt.plot(fedavg_test_08[30:], c='m')
plt.plot(fedavg_train_08[30:], c='c')
plt.plot(fedavg_test_05[30:], c='m')
plt.plot(fedavg_train_05[30:], c='c')
plt.plot(fedavg_test_02[30:], c='m')
plt.plot(fedavg_train_02[30:], c='c')
plt.legend(['FedAvg-Test-IID', 'FedAvg-Train-IID', 'FedAvg-Train-Pat', 'FedAvg-Test-Pat', 'FedAvg-Train-08', 'FedAvg-Test-08'])

# %%
for i in range(2000):
    if fedavg_train_iid[i]< 0.08:
        print(i)
        print(round(fedavg_test_iid[i]-fedavg_train_iid[i], 5))
        break
# Out:
# 8
# 0.00046

# %%
for i in range(1000):
    if fedavg_train_08[i]< 0.2:
        print(i)
        print(round(fedavg_test_08[i]-fedavg_train_08[i], 5))
        break
# Out:
# 8
# 0.00416

# %%
for i in range(1000):
    if fedavg_train_05[i]< 0.2:
        print(i)
        print(round(fedavg_test_05[i]-fedavg_train_05[i], 5))
        break
# Out:
# 4
# 0.00802

# %%
for i in range(1000):
    if fedavg_train_02[i]< 0.005:
        print(i)
        print(round(fedavg_test_02[i]-fedavg_train_02[i], 5))
        break
# Out:
# 222
# 0.04039

# %%
for i in range(2000):
    if fedavg_train_pat[i]< 0.2:
        print(i)
        print(round(fedavg_test_pat[i]-fedavg_train_pat[i], 5))
        break
# Out:
# 135
# 0.00503

# %%
plt.plot(fedavg_test_iid - fedavg_train_iid, c='r')
plt.plot(fedavg_test_pat - fedavg_train_pat, c='b')
plt.plot(fedavg_test_08 - fedavg_train_08, c='m')
plt.legend(['iid', 'pat', '08'])

# %%
plt.plot(scaffold_test_iid[30:], c='r')
plt.plot(scaffold_train_iid[30:], c='b')
plt.plot(scaffold_test_pat[30:], c='y')
plt.plot(scaffold_train_pat[30:], c='g')
#plt.plot(scaffold_test_08[30:], c='m')
#plt.plot(scaffold_train_08[30:], c='c')
#plt.plot(scaffold_test_05[30:], c='m')
#plt.plot(scaffold_train_05[30:], c='c')
plt.plot(scaffold_test_02[30:], c='m')
plt.plot(scaffold_train_02[30:], c='c')
#plt.legend(['scaffold-Test-IID', 'scaffold-Train-IID', 'scaffold-Train-Pat', 'scaffold-Test-Pat', 'scaffold-Train-08', 'scaffold-Test-08'])

# %%
plt.plot(scaffold_test_iid - scaffold_train_iid, c='r')
plt.plot(scaffold_test_pat - scaffold_train_pat, c='b')
#plt.plot(scaffold_test_08 - scaffold_train_08, c='m')
#plt.plot(scaffold_test_05 - scaffold_train_05, c='g')
plt.plot(scaffold_test_02 - scaffold_train_02, c='c')
#plt.legend(['iid', 'pat', '08'])

# %%
for i in range(2000):
    if scaffold_train_pat[i]< 0.6:
        print(i)
        print(abs(round(scaffold_test_pat[i]-scaffold_train_pat[i], 5)))
        break
# Out:
# 13
# 0.00475

# %%
for i in range(2000):
    if scaffold_train_iid[i]< 0.005:
        print(i)
        print(abs(round(scaffold_test_iid[i]-scaffold_train_iid[i], 5)))
        break
# Out:
# 515
# 0.02755

# %%
for i in range(2000):
    if scaffold_train_02[i]< 0.005:
        print(i)
        print(abs(round(scaffold_test_02[i]-scaffold_train_02[i], 5)))
        break
# Out:
# 722
# 0.03523

# %%
for i in range(2000):
    if scaffold_train_05[i]< 0.005:
        print(i)
        print(abs(round(scaffold_test_05[i]-scaffold_train_05[i], 5)))
        break
# Out:
# 592
# 0.03274

# %%
for i in range(2000):
    if scaffold_train_08[i]< 0.005:
        print(i)
        print(abs(round(scaffold_test_08[i]-scaffold_train_08[i], 5)))
        break
# Out:
# 880
# 0.04129

# %%
plt.plot(prox_test_08)
plt.plot(prox_train_08)

# %%
for i in range(2000):
    if prox_train_08[i]< 0.01:
        print(i)
        print(abs(round(prox_test_08[i]-prox_train_08[i], 5)))
        break
# Out:
# 47
# 0.01259
